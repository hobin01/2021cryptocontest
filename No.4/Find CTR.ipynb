# %%
"""
Z1,15로 Z2,1 Z2,4 Z2,10 Z2,15만 찾지말고
찾을 수 있는 거 다 찾아지는지 확인

Z2,i 구하는 연산에 Z1,15 포함된 경우
Z2,5 Z2,1 Z2,4 Z2,10 Z2,15 Z2,2 Z2,8
"""

# %matplotlib qt5
import numpy as np
import matplotlib.pyplot as plt
import struct

# %%
Sbox = [
    # S1
 [
  
 ],
    # S2
 [
  
 ],
    # inverse S1
 [
  
 ],
    # inverse S2
 [
  
 ]
]

# %%
HW=[
0, 1, 1, 2, 1, 2, 2, 3, 1, 2, 2, 3, 2, 3, 3, 4,
1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5,
1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5,
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6,
1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5,
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 
3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7, 
1, 2, 2, 3, 2, 3, 3, 4, 2, 3, 3, 4, 3, 4, 4, 5, 
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 
3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7, 
2, 3, 3, 4, 3, 4, 4, 5, 3, 4, 4, 5, 4, 5, 5, 6, 
3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7, 
3, 4, 4, 5, 4, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 7, 
4, 5, 5, 6, 5, 6, 6, 7, 5, 6, 6, 7, 6, 7, 7, 8
]

# %%
def DiffusionLayer(output_idx, Z):
    # Diffusion Layer 진행 후 값 리턴
    # Z : input이 되는 Z값 (list 형태로)
    
    result = 0
    
    if output_idx == 0 or output_idx == 5 or output_idx == 11 or output_idx == 14: 
        T = Z[3] ^ Z[4] ^ Z[9] ^ Z[14]
        
        if output_idx == 0:
            result = Z[6] ^ Z[8] ^ Z[13] ^ T
        elif output_idx == 5:
            result = Z[1] ^ Z[10] ^ Z[15] ^ T
        elif output_idx == 11:
            result = Z[2] ^ Z[7] ^ Z[12] ^ T
        elif output_idx == 14:
            result = Z[0] ^ Z[5] ^ Z[11] ^ T
    
    if output_idx == 1 or output_idx == 4 or output_idx == 10 or output_idx == 15:
        T = Z[2] ^ Z[5] ^ Z[8] ^ Z[15]
        
        if output_idx == 1:
            result = Z[7] ^ Z[9] ^ Z[12] ^ T
        elif output_idx == 4:
            result = Z[0] ^ Z[11] ^ Z[14] ^ T
        elif output_idx == 10:
            result = Z[3] ^ Z[6] ^ Z[13] ^ T
        elif output_idx == 15:
            result = Z[1] ^ Z[4] ^ Z[10] ^ T
    
    if output_idx == 2 or output_idx ==  7 or output_idx == 9 or output_idx == 12:
        T = Z[1] ^ Z[6] ^ Z[11] ^ Z[12]
        
        if output_idx == 2:
            result = Z[4] ^ Z[10] ^ Z[15] ^ T
        elif output_idx == 7:
            result = Z[3] ^ Z[8] ^ Z[13] ^ T
        elif output_idx == 9:
            result = Z[0] ^ Z[5] ^ Z[14] ^ T
        elif output_idx == 12:
            result = Z[2] ^ Z[7] ^ Z[9] ^ T
    
    if output_idx == 3 or output_idx == 6 or output_idx == 8 or output_idx == 13:
        T = Z[0] ^ Z[7] ^ Z[10] ^ Z[13]
        
        if output_idx == 3:
            result = Z[5] ^ Z[11] ^ Z[14] ^ T
        elif output_idx == 6:
            result = Z[2] ^ Z[9] ^ Z[12] ^ T
        elif output_idx == 8:
            result = Z[1] ^ Z[4] ^ Z[15] ^ T
        elif output_idx == 13:
            result = Z[3] ^ Z[6] ^ Z[8] ^ T
    
    return result

# %%
def rotate_right(num, bits):
    return (num >> bits) | ((num << (128-bits)) & 0xffffffffffffffffffffffffffffffff)

def rotate_left(num, bits):
    return ((num << bits) & 0xffffffffffffffffffffffffffffffff) | (num >> (128-bits))

# %%
# case4
K1_14 = 0b11100111
N14 = 0b01001110
K1_15 = 0b10101111
N15 = 0b01000111

C2_1 = 7
C2_2 = 76
C2_8 = 99
C2_10 = 3
C2_15 = 15
C2_4 = 148
C2_5 = 87

C3_0, C3_1, C3_2, C3_3, C3_4, C3_5, C3_6, C3_7 = 252, 187, 183, 16, 251, 117, 69, 22
C3_8, C3_9, C3_10, C3_11, C3_12, C3_13, C3_14, C3_15 = 176, 218, 53, 194, 79, 23, 10, 86

MK = 0x63727970746f6772617068796e696365
W0 = [99, 114, 121, 112, 116, 111, 103, 114, 97, 112, 104, 121, 110, 105, 99, 101]
C1 = [81, 124, 193, 183, 39, 34, 10, 148, 254, 19, 171, 232, 250, 154, 110, 224]
C2 = [109, 177, 74, 204, 158, 33, 200, 32, 255, 40, 177, 213, 239, 93, 226, 176]
C3 = [219, 146, 55, 29, 33, 38, 233, 112, 3, 36, 151, 117, 4, 232, 201, 14]

# %%
"""
i번쨰 라운드 복호화 키
dk_i = A(ek_(n+2-i))
dk_1 = ek_(n+1)
dk_(n+1) = ek_1

A : Diffusion Layer
암호문부터 내려오는 걸 1라운드부터로 생각 

ARIA128에서 MK = W0

복호화하기 
Z3 구할 수 있다
=> MK 알고 있으므로 10라운드부터 복호화하면 됨 (복호화 기준 10라운드 = 암호화 3라운드)
"""

# 필요한 복호화 키 구하기
# 10, 11, 12라운드 복호화 키
# dk10 = A(ek4), dk11 = A(ek3), dk12 = A(ek2), dk13 = ek1
# KR = 0

# W0,1,2,3
import copy

W1 = []
for i in range(16):
    W1.append(Sbox[i % 4][W0[i] ^ C1[i]])

tmp = []
for i in range(16):
    tmp.append(DiffusionLayer(i, W1))

W1 = tmp.copy()
tmp = []

W2 = []
s = 0
for i in range(16):
    if i % 4 == 0:
        s = 2
    elif i % 4 == 1:
        s = 3
    elif i % 4 == 2:
        s = 0
    elif i % 4 == 3:
        s = 1
    W2.append(Sbox[s][W1[i] ^ C2[i]])

for i in range(16):
    tmp.append(DiffusionLayer(i, W2))

for i in range(16):
    tmp[i] = tmp[i] ^ W0[i]

W2 = tmp.copy()
tmp = []

W3 = []
for i in range(16):
    W3.append(Sbox[i % 4][W2[i] ^ C3[i]])

for i in range(16):
    tmp.append(DiffusionLayer(i, W3))

for i in range(16):
    tmp[i] = tmp[i] ^ W1[i]

W3 = tmp.copy()

print("W0, W1, W2, W3")
print(W0)
print(W1)
print(W2)
print(W3)
print("====================")

# 복호화 키

num_W0 = MK
num_W1 = '0x'
num_W2 = '0x'
num_W3 = '0x'

for i in range(16):
    s1 = hex(W1[i])[2:]
    s2 = hex(W2[i])[2:]
    s3 = hex(W3[i])[2:]
    
    if len(s1) == 1:
        s1 = '0' + s1
    if len(s2) == 1:
        s2 = '0' + s2
    if len(s3) == 1:
        s3 = '0' + s3
    
    num_W1 += s1
    num_W2 += s2
    num_W3 += s3

num_W1 = int(num_W1, base=16)
num_W2 = int(num_W2, base=16)
num_W3 = int(num_W3, base=16)

print("W0, W1, W2, W3 hex")
print(hex(num_W0))
print(hex(num_W1))
print(hex(num_W2))
print(hex(num_W3))
print("====================")

W0shift19 = rotate_right(num_W0, 19)
W1shift19 = rotate_right(num_W1, 19)
W2shift19 = rotate_right(num_W2, 19)
W3shift19 = rotate_right(num_W3, 19)

num_ek1 = num_W0 ^ W1shift19
num_ek2 = num_W1 ^ W2shift19
num_ek3 = num_W2 ^ W3shift19
num_ek4 = num_W3 ^ W0shift19

print("ek1, ek2, ek3, ek4 hex")
print(hex(num_ek1))
print(hex(num_ek2))
print(hex(num_ek3))
print(hex(num_ek4))
print("=====================")

# 직접 찍어보니 ek1,2,3,4 다 32자리 16진수 
# dk10 = A(ek4), dk11 = A(ek3), dk12 = A(ek2), dk13 = ek1

EK4 = []
EK3 = []
EK2 = []
EK1 = []

ek1 = hex(num_ek1)
ek2 = hex(num_ek2)
ek3 = hex(num_ek3)
ek4 = hex(num_ek4)

for i in range(2, len(ek1), 2):
    s1 = ek1[i:i+2]
    s2 = ek2[i:i+2]
    s3 = ek3[i:i+2]
    s4 = ek4[i:i+2]
    
    if len(s1) == 1:
        s1 = '0' + s1
    if len(s2) == 1:
        s2 = '0' + s2
    if len(s3) == 1:
        s3 = '0' + s3
    if len(s4) == 1:
        s4 = '0' + s4
    
    n1 = int('0x'+s1, base=16)
    n2 = int('0x'+s2, base=16)
    n3 = int('0x'+s3, base=16)
    n4 = int('0x'+s4, base=16)
    
    EK1.append(n1)
    EK2.append(n2)
    EK3.append(n3)
    EK4.append(n4)

print("ek1, ek2, ek3, ek4 list")
print(EK1)
print(EK2)
print(EK3)
print(EK4)
print("==========================")

DK10 = []
DK11 = []
DK12 = []
DK13 = []

for i in range(16):
    DK10.append(DiffusionLayer(i, EK4))
    DK11.append(DiffusionLayer(i, EK3))
    DK12.append(DiffusionLayer(i, EK2))
    DK13.append(EK1[i])

print("dk10, dk11, dk12, dk13 list")
print(DK10)
print(DK11)
print(DK12)
print(DK13)
print("=========================")
# Out:
# W0, W1, W2, W3
# [99, 114, 121, 112, 116, 111, 103, 114, 97, 112, 104, 121, 110, 105, 99, 101]
# [185, 155, 181, 254, 207, 250, 236, 120, 53, 162, 21, 28, 38, 86, 63, 13]
# [200, 186, 153, 204, 88, 101, 46, 69, 200, 81, 255, 86, 36, 223, 157, 44]
# [97, 207, 228, 5, 187, 0, 21, 105, 58, 238, 178, 207, 227, 209, 240, 219]
# ...
# W0, W1, W2, W3 hex
# 0x63727970746f6772617068796e696365
# 0xb99bb5fecffaec7835a2151c26563f0d
# 0xc8ba99cc58652e45c851ff5624df9d2c
# 0x61cfe405bb0015693aeeb2cfe3d1f0db
# ...
# ek1, ek2, ek3, ek4 hex
# 0xa493ce4302d0be8d3cff6ecd2ccae7af
# 0x4a3e2ce99cc36774906aac1619bcfb96
# 0xf6a1f5f5a4e59925cafcd80bf2866156
# 0x4da3486bf42e1be4d600fee1eededd16
# ...
# ek1, ek2, ek3, ek4 list
# [164, 147, 206, 67, 2, 208, 190, 141, 60, 255, 110, 205, 44, 202, 231, 175]
# [74, 62, 44, 233, 156, 195, 103, 116, 144, 106, 172, 22, 25, 188, 251, 150]
# [246, 161, 245, 245, 164, 229, 153, 37, 202, 252, 216, 11, 242, 134, 97, 86]
# ...

# %%
# t = 0 일 때 복호화한 블럭 X1 = CTR

X1_15 = N15
Y1_15 = K1_15 ^ X1_15
X1_14 = N14
Y1_14 = K1_14 ^ X1_14

Z1_15 = Sbox[3][Y1_15]
Z1_14 = Sbox[2][Y1_14]

Z2_1 = Sbox[3][C2_1 ^ Z1_15]
Z2_2 = Sbox[0][C2_2 ^ Z1_15]
Z2_8 = Sbox[2][C2_8 ^ Z1_15]
Z2_10 = Sbox[0][C2_10 ^ Z1_15]
Z2_15 = Sbox[1][C2_15 ^ Z1_15]

Z2_4 = Sbox[2][C2_4 ^ Z1_14 ^ Z1_15]
Z2_5 = Sbox[3][C2_5 ^ Z1_14 ^ Z1_15]

Z3_0 = Sbox[0][C3_0 ^ Z2_8 ^ Z2_4]
Z3_1 = Sbox[1][C3_1 ^ Z2_2 ^ Z2_5 ^ Z2_8 ^ Z2_15]
Z3_2 = Sbox[2][C3_2 ^ Z2_4 ^ Z2_10 ^ Z2_15 ^ Z2_1]
Z3_3 = Sbox[3][C3_3 ^ Z2_5 ^ Z2_10]

Z3_4 = Sbox[0][C3_4 ^ Z2_2 ^ Z2_5 ^ Z2_8 ^ Z2_15]
Z3_5 = Sbox[1][C3_5 ^ Z2_1 ^ Z2_10 ^ Z2_15 ^ Z2_4]
Z3_6 = Sbox[2][C3_6 ^ Z2_2 ^ Z2_10]
Z3_7 = Sbox[3][C3_7 ^ Z2_8 ^ Z2_1]

Z3_8 = Sbox[0][C3_8 ^ Z2_1 ^ Z2_4 ^ Z2_15 ^ Z2_10]
Z3_9 = Sbox[1][C3_9 ^ Z2_5 ^ Z2_1]
Z3_10 = Sbox[2][C3_10 ^ Z2_2 ^ Z2_5 ^ Z2_8 ^ Z2_15]
Z3_11 = Sbox[3][C3_11 ^ Z2_2 ^ Z2_4]

Z3_12 = Sbox[0][C3_12 ^ Z2_2 ^ Z2_1]
Z3_13 = Sbox[1][C3_13 ^ Z2_8 ^ Z2_10]
Z3_14 = Sbox[2][C3_14 ^ Z2_5 ^ Z2_4]
Z3_15 = Sbox[3][C3_15 ^ Z2_1 ^ Z2_4 ^ Z2_10 ^ Z2_2 ^ Z2_5 ^ Z2_8 ^ Z2_15]

Z3 = [Z3_0, Z3_1, Z3_2, Z3_3, Z3_4, Z3_5, Z3_6, Z3_7, Z3_8, Z3_9, Z3_10, Z3_11, Z3_12, Z3_13, Z3_14, Z3_15]

print("Z3")
print(Z3)
print("==================")

Y3 = []
s = 0
for i in range(16):
    if i % 4 == 0:
        s = 2
    elif i % 4 == 1:
        s = 3
    elif i % 4 == 2:
        s = 0
    elif i % 4 == 3:
        s = 1
    Y3.append(Sbox[s][Z3[i]])

X3 = []
for i in range(16):
    X3.append(Y3[i] ^ EK3[i])

Z2 = []
for i in range(16):
    Z2.append(DiffusionLayer(i, X3))

Y2 = []
for i in range(16):
    Y2.append(Sbox[i % 4][Z2[i]])

X2 = []
for i in range(16):
    X2.append(Y2[i] ^ EK2[i])

Z1 = []
for i in range(16):
    Z1.append(DiffusionLayer(i, X2))

Y1 = []
s = 0
for i in range(16):
    if i % 4 == 0:
        s = 2
    elif i % 4 == 1:
        s = 3
    elif i % 4 == 2:
        s = 0
    elif i % 4 == 3:
        s = 1
    Y1.append(Sbox[s][Z1[i]])

X1 = []
for i in range(16):
    X1.append(Y1[i] ^ EK1[i])

print("CTR")
print(X1)
# Out:
# Z3
# [157, 209, 227, 157, 132, 239, 153, 254, 71, 247, 145, 11, 248, 225, 124, 142]
# ...
# CTR
# [67, 82, 89, 80, 84, 79, 73, 83, 70, 85, 78, 84, 72, 73, 78, 71]
